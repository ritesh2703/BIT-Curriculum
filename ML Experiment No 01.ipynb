# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Youtuber.csv')

# %%
df.head()
# Out:
#    Rank                Channel Name       Category Subscribers        Country  \
# 0   NaN                         NaN            NaN         NaN            NaN
# 1   1.0                    T-Series  Music & Dance      258.4M          India
# 2   2.0                     MrBeast    Video games      236.1M  United States
# 3   3.0  Cocomelon - Nursery Rhymes      Education      171.4M            NaN
# 4   4.0                   SET India            NaN      167.1M          India
#
#   Average Views Average Likes Average Comments Content Type
# 0           NaN           NaN              NaN          NaN
# 1        135.2K          5.6K              223          NaN
# 2          104M            4M              74K        Humor
# 3          5.1M         57.1K                0          NaN
# 4         27.9K           996                7          NaN

# %%
df.shape
# Out:
# (1046, 9)

# %% [markdown]
# # Head

# %%
df.describe()
# Out:
#               Rank
# count  1045.000000
# mean    521.055502
# std     298.709262
# min       1.000000
# 25%     262.000000
# 50%     523.000000
# 75%     784.000000
# max    1000.000000

# %%
df.head()
# Out:
#    Rank                Channel Name       Category Subscribers        Country  \
# 0   NaN                         NaN            NaN         NaN            NaN
# 1   1.0                    T-Series  Music & Dance      258.4M          India
# 2   2.0                     MrBeast    Video games      236.1M  United States
# 3   3.0  Cocomelon - Nursery Rhymes      Education      171.4M            NaN
# 4   4.0                   SET India            NaN      167.1M          India
#
#   Average Views Average Likes Average Comments Content Type
# 0           NaN           NaN              NaN          NaN
# 1        135.2K          5.6K              223          NaN
# 2          104M            4M              74K        Humor
# 3          5.1M         57.1K                0          NaN
# 4         27.9K           996                7          NaN

# %%
df.tail()
# Out:
#         Rank    Channel Name       Category Subscribers        Country  \
# 1041   996.0       BBC Earth            NaN       12.5M  United States
# 1042   997.0    Jamie Nyland      Animation       12.5M  United States
# 1043   998.0  janin al chair            NaN       12.5M         Mexico
# 1044   999.0     Myke Towers  Music & Dance       12.5M       Colombia
# 1045  1000.0       HikakinTV          Humor       12.5M          Japan
#
#      Average Views Average Likes Average Comments Content Type
# 1041         80.3K          1.7K               79          NaN
# 1042         66.7K          2.5K              104        Humor
# 1043          1.4M        146.1K              485          NaN
# 1044          8.3K           485                8          NaN
# 1045        703.2K         25.3K              312          NaN

# %%
df.shape
# Out:
# (1046, 9)

# %%
df.shape
# Out:
# (1046, 9)

# %%
df.isnull()
# Out:
#        Rank  Channel Name  Category  Subscribers  Country  Average Views  \
# 0      True          True      True         True     True           True
# 1     False         False     False        False    False          False
# 2     False         False     False        False    False          False
# 3     False         False     False        False     True          False
# 4     False         False      True        False    False          False
# ...     ...           ...       ...          ...      ...            ...
# 1041  False         False      True        False    False          False
# 1042  False         False     False        False    False          False
# 1043  False         False      True        False    False          False
# 1044  False         False     False        False    False          False
# 1045  False         False     False        False    False          False
#
#       Average Likes  Average Comments  Content Type
# ...

# %%
df.isnull().sum()
# Out:
# Rank                  1
# Channel Name          1
# Category            351
# Subscribers           1
# Country             193
# Average Views         1
# Average Likes         1
# Average Comments      1
# Content Type        711
# dtype: int64

# %%
import pandas as pd

# %%
df = pd.read_csv('kaggle_sw_errorfunc_descending_v01.csv')

# %%
df.shape
# Out:
# (104345, 15)

# %%
df
# Out:
#           rank                                  branch  percentile  \
# 0        28379                  Mechanical Engineering   84.681193
# 1         4997  Electronics and Telecommunication Engg   90.095562
# 2        12535                  Mechanical Engineering   78.452705
# 3        23319                  Mechanical Engineering   87.434605
# 4        14007                       Civil Engineering   92.473577
# ...        ...                                     ...         ...
# 104340  120870                    Computer Engineering    3.350124
# 104341  119127                    Computer Engineering    6.377115
# 104342  117488                  Mechanical Engineering    8.758330
# 104343  119303                    Computer Engineering    5.903569
# 104344  122443  Electronics and Telecommunication Engg    0.428998
#
#         mean_percentile      error category seat_type  \
# 0             17.705766  66.975427     OPEN    GOPENH
# ...

# %%
df.head()
# Out:
#     rank                                  branch  percentile  mean_percentile  \
# 0  28379                  Mechanical Engineering   84.681193        17.705766
# 1   4997  Electronics and Telecommunication Engg   90.095562        26.459724
# 2  12535                  Mechanical Engineering   78.452705        16.300571
# 3  23319                  Mechanical Engineering   87.434605        27.660462
# 4  14007                       Civil Engineering   92.473577        32.757016
#
#        error category seat_type  \
# 0  66.975427     OPEN    GOPENH
# 1  63.635838      OBC        AI
# 2  62.152135      SC$        AI
# 3  59.774143     OPEN       EWS
# 4  59.716561      OBC    GOPENH
#
#                                         college_name        primary_seat_type  \
# 0  Samarth Education Trust's Arvind Gavali Colleg...  Maharashtra State Seats
# 1                  Karmayogi Institute of Technology          All India Seats
# ...

# %%
df.tail(3)
# Out:
#           rank                                  branch  percentile  \
# 104342  117488                  Mechanical Engineering    8.758330
# 104343  119303                    Computer Engineering    5.903569
# 104344  122443  Electronics and Telecommunication Engg    0.428998
#
#         mean_percentile      error category seat_type  \
# 104342        67.071242 -58.312911     OPEN        MI
# 104343        66.333786 -60.430218       ST      GSTH
# 104344        62.054420 -61.625421       ST      GSTS
#
#                                              college_name  \
# 104342  Shri Vile Parle Kelvani Mandal's Dwarkadas J. ...
# 104343  Sinhgad Academy of Engineering, Kondhwa (BK)  ...
# 104344           Government College of Engineering, Karad
#
#               primary_seat_type  \
# 104342        State Level Seats
# 104343  Maharashtra State Seats
# 104344        State Level Seats
#
#                                       secondary_seat_type score_type  \
# ...

# %%
df.describe()
# Out:
#                 rank     percentile  mean_percentile         error
# count  104345.000000  104345.000000    104345.000000  1.043450e+05
# mean    53628.903819      63.394483        63.394483  1.399617e-12
# std     35253.231789      26.219450        24.958650  8.032766e+00
# min         0.000000       0.004739         0.004739 -6.162542e+01
# 25%     22737.000000      45.271811        43.618042 -1.806277e+00
# 50%     49145.000000      69.286946        67.974599  0.000000e+00
# 75%     82395.000000      85.040326        84.508606  1.383606e+00
# max    129286.000000     100.000000        99.910161  6.697543e+01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   rank                 104345 non-null  int64
#  1   branch               104345 non-null  object
#  2   percentile           104345 non-null  float64
#  3   mean_percentile      104345 non-null  float64
#  4   error                104345 non-null  float64
#  5   category             104345 non-null  object
#  6   seat_type            104345 non-null  object
#  7   college_name         104345 non-null  object
#  8   primary_seat_type    104345 non-null  object
#  9   secondary_seat_type  104345 non-null  object
#  10  score_type           104345 non-null  object
#  11  enrollment_no        104345 non-null  object
#  12  branch_code          104345 non-null  object
#  13  gender               104345 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# rank                   0
# branch                 0
# percentile             0
# mean_percentile        0
# error                  0
# category               0
# seat_type              0
# college_name           0
# primary_seat_type      0
# secondary_seat_type    0
# score_type             0
# enrollment_no          0
# branch_code            0
# gender                 0
# fulfillment            0
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#           rank                                  branch  percentile  \
# 0        28379                  Mechanical Engineering   84.681193
# 1         4997  Electronics and Telecommunication Engg   90.095562
# 2        12535                  Mechanical Engineering   78.452705
# 3        23319                  Mechanical Engineering   87.434605
# 4        14007                       Civil Engineering   92.473577
# ...        ...                                     ...         ...
# 104340  120870                    Computer Engineering    3.350124
# 104341  119127                    Computer Engineering    6.377115
# 104342  117488                  Mechanical Engineering    8.758330
# 104343  119303                    Computer Engineering    5.903569
# 104344  122443  Electronics and Telecommunication Engg    0.428998
#
#         mean_percentile      error category seat_type  \
# 0             17.705766  66.975427     OPEN    GOPENH
# ...

# %%
df[0:4]
# Out:
#     rank                                  branch  percentile  mean_percentile  \
# 0  28379                  Mechanical Engineering   84.681193        17.705766
# 1   4997  Electronics and Telecommunication Engg   90.095562        26.459724
# 2  12535                  Mechanical Engineering   78.452705        16.300571
# 3  23319                  Mechanical Engineering   87.434605        27.660462
#
#        error category seat_type  \
# 0  66.975427     OPEN    GOPENH
# 1  63.635838      OBC        AI
# 2  62.152135      SC$        AI
# 3  59.774143     OPEN       EWS
#
#                                         college_name        primary_seat_type  \
# 0  Samarth Education Trust's Arvind Gavali Colleg...  Maharashtra State Seats
# 1                  Karmayogi Institute of Technology          All India Seats
# 2  Vidarbha Bahu-Uddeshiya Shikshan Sanstha's Tul...          All India Seats
# 3  Shetkari Shikshan Mandal's Pad. Vasantraodada ...        State Level Seats
#
# ...

# %%
min(df['branch'])
# Out:
# 'Aeronautical Engineering'

# %%
max(df['percentile'])
# Out:
# 100.0

# %%
df.isna()
# Out:
#          rank  branch  percentile  mean_percentile  error  category  \
# 0       False   False       False            False  False     False
# 1       False   False       False            False  False     False
# 2       False   False       False            False  False     False
# 3       False   False       False            False  False     False
# 4       False   False       False            False  False     False
# ...       ...     ...         ...              ...    ...       ...
# 104340  False   False       False            False  False     False
# 104341  False   False       False            False  False     False
# 104342  False   False       False            False  False     False
# 104343  False   False       False            False  False     False
# 104344  False   False       False            False  False     False
#
#         seat_type  college_name  primary_seat_type  secondary_seat_type  \
# 0           False         False              False                False
# ...

# %%
df['rank']
# Out:
# 0          28379
# 1           4997
# 2          12535
# 3          23319
# 4          14007
#            ...
# 104340    120870
# 104341    119127
# 104342    117488
# 104343    119303
# 104344    122443
# Name: rank, Length: 104345, dtype: int64

# %%
df.value_counts()
# Out:
# rank    branch                                         percentile  mean_percentile  error      category     seat_type  college_name                                                                      primary_seat_type        secondary_seat_type                                                                 score_type  enrollment_no  branch_code  gender  fulfillment
# 0       Artificial Intelligence (AI) and Data Science  23.488892   23.488892         0.000000  OPEN         ORPHAN     Sanmati Engineering College, Sawargaon Barde, Washim                              State Level Seats        ORPHAN Seats                                                                        MHT-CET     EN22112643     118026310    M       &              1
# ...

# %%
df[df['rank']=='kaggle_sw_errorfunc_descending_v01']
# Out:
# Empty DataFrame
# Columns: [rank, branch, percentile, mean_percentile, error, category, seat_type, college_name, primary_seat_type, secondary_seat_type, score_type, enrollment_no, branch_code, gender, fulfillment]
# Index: []

# %%
df
# Out:
#           rank                                  branch  percentile  \
# 0        28379                  Mechanical Engineering   84.681193
# 1         4997  Electronics and Telecommunication Engg   90.095562
# 2        12535                  Mechanical Engineering   78.452705
# 3        23319                  Mechanical Engineering   87.434605
# 4        14007                       Civil Engineering   92.473577
# ...        ...                                     ...         ...
# 104340  120870                    Computer Engineering    3.350124
# 104341  119127                    Computer Engineering    6.377115
# 104342  117488                  Mechanical Engineering    8.758330
# 104343  119303                    Computer Engineering    5.903569
# 104344  122443  Electronics and Telecommunication Engg    0.428998
#
#         mean_percentile      error category seat_type  \
# 0             17.705766  66.975427     OPEN    GOPENH
# ...

# %%
df.shape
# Out:
# (104345, 15)

# %%
df.isnull().sum()
# Out:
# rank                   0
# branch                 0
# percentile             0
# mean_percentile        0
# error                  0
# category               0
# seat_type              0
# college_name           0
# primary_seat_type      0
# secondary_seat_type    0
# score_type             0
# enrollment_no          0
# branch_code            0
# gender                 0
# fulfillment            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   rank                 104345 non-null  int64
#  1   branch               104345 non-null  object
#  2   percentile           104345 non-null  float64
#  3   mean_percentile      104345 non-null  float64
#  4   error                104345 non-null  float64
#  5   category             104345 non-null  object
#  6   seat_type            104345 non-null  object
#  7   college_name         104345 non-null  object
#  8   primary_seat_type    104345 non-null  object
#  9   secondary_seat_type  104345 non-null  object
#  10  score_type           104345 non-null  object
#  11  enrollment_no        104345 non-null  object
#  12  branch_code          104345 non-null  object
#  13  gender               104345 non-null  object
# ...

# %%
#b) Reshaping, Filtering, Scaling, Merging the data and 
#Handling the missing values in datasets.

# %%
import numpy as np

# %%
from sklearn.impute import SimpleImputer

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
imp_mean.fit([[7, 2, 3], [4, np.nan, 6], [10, 5, 9]])
# Out:
# SimpleImputer()

# %%
X = [[np.nan, 2, 3], [4, np.nan, 6], [10, np.nan, 9]]

# %%
print(imp_mean.transform(X))
# Out:
# [[ 7.   2.   3. ]
#  [ 4.   3.5  6. ]
#  [10.   3.5  9. ]]

# %%
X
# Out:
# [[nan, 2, 3], [4, nan, 6], [10, nan, 9]]

# %%
z = imp_mean.transform(X)

# %%
z
# Out:
# array([[ 7. ,  2. ,  3. ],
#        [ 4. ,  3.5,  6. ],
#        [10. ,  3.5,  9. ]])

# %%
#sklearn.preprocessing.MinMaxScaler

# %% [markdown]
# # Creating the Dataset

# %%
employee = ['Ritesh', 'Pranay', 'Sumit', 'Prathmesh', 'Kartik', 'Ramesh', 'Tukaram', 'Ananta', 'Mahadev', 'Sankar']

# %%
age = [25, 29, 30, 28, 40, 25, 'nan', 27, 50, 47]

# %%
salary = [48000, 45000, 54000, 65000, 'nan', 58000, 53000, 79000, 88000, 77000]

# %%
len(salary)
# Out:
# 10

# %%
df_data = pd.DataFrame({'Employee':employee, 'Age' : age, 'Salary' : salary})

# %%
df_data
# Out:
#     Employee  Age Salary
# 0     Ritesh   25  48000
# 1     Pranay   29  45000
# 2      Sumit   30  54000
# 3  Prathmesh   28  65000
# 4     Kartik   40    nan
# 5     Ramesh   25  58000
# 6    Tukaram  nan  53000
# 7     Ananta   27  79000
# 8    Mahadev   50  88000
# 9     Sankar   47  77000

# %%
Computer_Engineer  = ['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes']

# %%
df_Computer_Engineer = pd.DataFrame(Computer_Engineer, columns=['Computer_Engineer'])

# %%
df_Computer_Engineer
# Out:
#   Computer_Engineer
# 0                No
# 1               Yes
# 2                No
# 3                No
# 4               Yes
# 5               Yes
# 6                No
# 7               Yes
# 8                No
# 9               Yes

# %%
df_data1 = pd.DataFrame({'Employee' :employee , 'Computer_Engineer' : Computer_Engineer})

# %%
df_data1
# Out:
#     Employee Computer_Engineer
# 0     Ritesh                No
# 1     Pranay               Yes
# 2      Sumit                No
# 3  Prathmesh                No
# 4     Kartik               Yes
# 5     Ramesh               Yes
# 6    Tukaram                No
# 7     Ananta               Yes
# 8    Mahadev                No
# 9     Sankar               Yes

# %%
#Mearging the dataframe
Employee_data = df_data.merge(df_data1, how='inner', on='Employee')

# %%
#Saving dataset to Csv
Employee_data.to_csv('Employee.csv',index=False)

# %%
Employee_data
# Out:
#     Employee  Age Salary Computer_Engineer
# 0     Ritesh   25  48000                No
# 1     Pranay   29  45000               Yes
# 2      Sumit   30  54000                No
# 3  Prathmesh   28  65000                No
# 4     Kartik   40    nan               Yes
# 5     Ramesh   25  58000               Yes
# 6    Tukaram  nan  53000                No
# 7     Ananta   27  79000               Yes
# 8    Mahadev   50  88000                No
# 9     Sankar   47  77000               Yes

# %% [markdown]
# # loading different datasets

# %%
df2 = pd.read_csv('Employee.csv')

# %%
df2
# Out:
#     Employee   Age   Salary Computer_Engineer
# 0     Ritesh  25.0  48000.0                No
# 1     Pranay  29.0  45000.0               Yes
# 2      Sumit  30.0  54000.0                No
# 3  Prathmesh  28.0  65000.0                No
# 4     Kartik  40.0      NaN               Yes
# 5     Ramesh  25.0  58000.0               Yes
# 6    Tukaram   NaN  53000.0                No
# 7     Ananta  27.0  79000.0               Yes
# 8    Mahadev  50.0  88000.0                No
# 9     Sankar  47.0  77000.0               Yes

# %% [markdown]
# # Handaling Missing Data

# %%
df2.isnull().sum()
# Out:
# Employee             0
# Age                  1
# Salary               1
# Computer_Engineer    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
import numpy as np

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
df2_trans1 = imputer.fit_transform(df2)

# %%
# Not able to Handle missing values as dataframe contans categorical data

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df2.head()
# Out:
#     Employee   Age   Salary Computer_Engineer
# 0     Ritesh  25.0  48000.0                No
# 1     Pranay  29.0  45000.0               Yes
# 2      Sumit  30.0  54000.0                No
# 3  Prathmesh  28.0  65000.0                No
# 4     Kartik  40.0      NaN               Yes

# %%
encoder = LabelEncoder()

# %%
df_trans2 = pd.DataFrame()

# %%
df_trans2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_trans2['Employee'] = encoder.fit_transform(df2['Employee'])

# %%
df_trans2
# Out:
#    Employee
# 0         6
# 1         3
# 2         8
# 3         4
# 4         1
# 5         5
# 6         9
# 7         0
# 8         2
# 9         7

# %%
df2['Employee']
# Out:
# 0       Ritesh
# 1       Pranay
# 2        Sumit
# 3    Prathmesh
# 4       Kartik
# 5       Ramesh
# 6      Tukaram
# 7       Ananta
# 8      Mahadev
# 9       Sankar
# Name: Employee, dtype: object

# %%
df2
# Out:
#     Employee   Age   Salary Computer_Engineer
# 0     Ritesh  25.0  48000.0                No
# 1     Pranay  29.0  45000.0               Yes
# 2      Sumit  30.0  54000.0                No
# 3  Prathmesh  28.0  65000.0                No
# 4     Kartik  40.0      NaN               Yes
# 5     Ramesh  25.0  58000.0               Yes
# 6    Tukaram   NaN  53000.0                No
# 7     Ananta  27.0  79000.0               Yes
# 8    Mahadev  50.0  88000.0                No
# 9     Sankar  47.0  77000.0               Yes

# %%
df_trans2
# Out:
#    Employee
# 0         6
# 1         3
# 2         8
# 3         4
# 4         1
# 5         5
# 6         9
# 7         0
# 8         2
# 9         7

# %%
df_trans2['Age'] = df2['Age']
df_trans2['Salary'] = df2['Salary']
df_trans2['Computer_Engineer'] = encoder.fit_transform(df2['Computer_Engineer'])

# %%
df_trans2
# Out:
#    Employee   Age   Salary  Computer_Engineer
# 0         6  25.0  48000.0                  0
# 1         3  29.0  45000.0                  1
# 2         8  30.0  54000.0                  0
# 3         4  28.0  65000.0                  0
# 4         1  40.0      NaN                  1
# 5         5  25.0  58000.0                  1
# 6         9   NaN  53000.0                  0
# 7         0  27.0  79000.0                  1
# 8         2  50.0  88000.0                  0
# 9         7  47.0  77000.0                  1

# %%
df_trans2.isnull().sum()
# Out:
# Employee             0
# Age                  1
# Salary               1
# Computer_Engineer    0
# dtype: int64

# %%
#Now all column data is in numner now we can handle missing data.

# %%
from sklearn.impute import SimpleImputer

# %%
import numpy as np

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
df2_trans1 = imputer.fit_transform(df_trans2)

# %%
df2_trans1
# Out:
# array([[6.00000000e+00, 2.50000000e+01, 4.80000000e+04, 0.00000000e+00],
#        [3.00000000e+00, 2.90000000e+01, 4.50000000e+04, 1.00000000e+00],
#        [8.00000000e+00, 3.00000000e+01, 5.40000000e+04, 0.00000000e+00],
#        [4.00000000e+00, 2.80000000e+01, 6.50000000e+04, 0.00000000e+00],
#        [1.00000000e+00, 4.00000000e+01, 6.30000000e+04, 1.00000000e+00],
#        [5.00000000e+00, 2.50000000e+01, 5.80000000e+04, 1.00000000e+00],
#        [9.00000000e+00, 3.34444444e+01, 5.30000000e+04, 0.00000000e+00],
#        [0.00000000e+00, 2.70000000e+01, 7.90000000e+04, 1.00000000e+00],
#        [2.00000000e+00, 5.00000000e+01, 8.80000000e+04, 0.00000000e+00],
#        [7.00000000e+00, 4.70000000e+01, 7.70000000e+04, 1.00000000e+00]])

# %%
df2_trans1 = pd.DataFrame(df2_trans1)

# %%
df2_trans1
# Out:
#      0          1        2    3
# 0  6.0  25.000000  48000.0  0.0
# 1  3.0  29.000000  45000.0  1.0
# 2  8.0  30.000000  54000.0  0.0
# 3  4.0  28.000000  65000.0  0.0
# 4  1.0  40.000000  63000.0  1.0
# 5  5.0  25.000000  58000.0  1.0
# 6  9.0  33.444444  53000.0  0.0
# 7  0.0  27.000000  79000.0  1.0
# 8  2.0  50.000000  88000.0  0.0
# 9  7.0  47.000000  77000.0  1.0

# %%
df2_trans1.isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %% [markdown]
# # Creating Dependent and Indepent columns : X and Y

# %%
df2_trans1
# Out:
#      0          1        2    3
# 0  6.0  25.000000  48000.0  0.0
# 1  3.0  29.000000  45000.0  1.0
# 2  8.0  30.000000  54000.0  0.0
# 3  4.0  28.000000  65000.0  0.0
# 4  1.0  40.000000  63000.0  1.0
# 5  5.0  25.000000  58000.0  1.0
# 6  9.0  33.444444  53000.0  0.0
# 7  0.0  27.000000  79000.0  1.0
# 8  2.0  50.000000  88000.0  0.0
# 9  7.0  47.000000  77000.0  1.0

# %%
df2_trans1.shape
# Out:
# (10, 4)

# %%
X = pd.DataFrame(df2_trans1.iloc[:, 0:3].values)

# %%
X
# Out:
#      0          1        2
# 0  6.0  25.000000  48000.0
# 1  3.0  29.000000  45000.0
# 2  8.0  30.000000  54000.0
# 3  4.0  28.000000  65000.0
# 4  1.0  40.000000  63000.0
# 5  5.0  25.000000  58000.0
# 6  9.0  33.444444  53000.0
# 7  0.0  27.000000  79000.0
# 8  2.0  50.000000  88000.0
# 9  7.0  47.000000  77000.0

# %%
Y = pd.DataFrame(df2_trans1.iloc[:, -1].values)

# %%
Y = pd.DataFrame(df2_trans1.iloc[:, 3:].values)

# %%
Y
# Out:
#      0
# 0  0.0
# 1  1.0
# 2  0.0
# 3  0.0
# 4  1.0
# 5  1.0
# 6  0.0
# 7  1.0
# 8  0.0
# 9  1.0

# %% [markdown]
# # Feature Scaling of DataSet- MinMaxScalar

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar = MinMaxScaler()

# %%
X_scaled = pd.DataFrame(scalar.fit_transform(X))

# %%
X_scaled
# Out:
#           0         1         2
# 0  0.666667  0.000000  0.069767
# 1  0.333333  0.160000  0.000000
# 2  0.888889  0.200000  0.209302
# 3  0.444444  0.120000  0.465116
# 4  0.111111  0.600000  0.418605
# 5  0.555556  0.000000  0.302326
# 6  1.000000  0.337778  0.186047
# 7  0.000000  0.080000  0.790698
# 8  0.222222  1.000000  1.000000
# 9  0.777778  0.880000  0.744186

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=2)

# %%
X_train
# Out:
#      0          1        2
# 0  6.0  25.000000  48000.0
# 7  0.0  27.000000  79000.0
# 2  8.0  30.000000  54000.0
# 3  4.0  28.000000  65000.0
# 6  9.0  33.444444  53000.0
# 9  7.0  47.000000  77000.0
# 8  2.0  50.000000  88000.0

# %%
X_train.shape
# Out:
# (7, 3)

# %%
X_test.shape
# Out:
# (3, 3)

# %%
y_train.shape
# Out:
# (7, 1)

# %%
X_test
# Out:
#      0     1        2
# 4  1.0  40.0  63000.0
# 1  3.0  29.0  45000.0
# 5  5.0  25.0  58000.0

# %%
X_test.shape
# Out:
# (3, 3)

# %%
y_test
# Out:
#      0
# 4  1.0
# 1  1.0
# 5  1.0

# %%
y_test.shape
# Out:
# (3, 1)

# %%
df2
# Out:
#     Employee   Age   Salary Computer_Engineer
# 0     Ritesh  25.0  48000.0                No
# 1     Pranay  29.0  45000.0               Yes
# 2      Sumit  30.0  54000.0                No
# 3  Prathmesh  28.0  65000.0                No
# 4     Kartik  40.0      NaN               Yes
# 5     Ramesh  25.0  58000.0               Yes
# 6    Tukaram   NaN  53000.0                No
# 7     Ananta  27.0  79000.0               Yes
# 8    Mahadev  50.0  88000.0                No
# 9     Sankar  47.0  77000.0               Yes

# %%
df2.shape
# Out:
# (10, 4)

# %%
X_test.shape
# Out:
# (3, 3)

# %%
y_test.shape
# Out:
# (3, 1)
